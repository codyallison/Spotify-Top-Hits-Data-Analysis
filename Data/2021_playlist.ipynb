# %%
import requests
from config import client_id
from config import client_secret
from formulas import get_playlist_songs,get_track_features
import pandas as pd

# %%
tracks_df_21 = pd.read_csv('spotify_top50_2021.csv')

# %%
tracks_df_21 =tracks_df_21.rename(columns = {'duration_ms': 'duration (ms)','tempo':'bpm', 
                                             'artist_name': 'Artist', 'track_name': 'Song Title', 'track_id': 'Song ID'})
                              
tracks_df_21['duration (secs)'] = tracks_df_21['duration (ms)']/1000
tracks_df_21['top year'] = '2021'
tracks_df_21
# Out:
#     id             Artist                                         Song Title  \
# 0    1     Olivia Rodrigo                                    drivers license
# 1    2          Lil Nas X                     MONTERO (Call Me By Your Name)
# 2    3      The Kid LAROI                          STAY (with Justin Bieber)
# 3    4     Olivia Rodrigo                                           good 4 u
# 4    5           Dua Lipa                          Levitating (feat. DaBaby)
# 5    6      Justin Bieber             Peaches (feat. Daniel Caesar & Giveon)
# 6    7           Doja Cat                           Kiss Me More (feat. SZA)
# 7    8         The Weeknd                                    Blinding Lights
# 8    9      Glass Animals                                         Heat Waves
# 9   10           Måneskin                                            Beggin'
# 10  11        Masked Wolf                             Astronaut In The Ocean
# ...

# %%
tracks_df_21['top year'] = '2021'
tracks_df_21 = tracks_df_21[['Song Title', 'Artist', 'Song ID', 'popularity', 'danceability',
       'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'bpm', 'duration (ms)',
       'duration (secs)', 'top year']]
tracks_df_21
# Out:
#                                            Song Title             Artist  \
# 0                                     drivers license     Olivia Rodrigo
# 1                      MONTERO (Call Me By Your Name)          Lil Nas X
# 2                           STAY (with Justin Bieber)      The Kid LAROI
# 3                                            good 4 u     Olivia Rodrigo
# 4                           Levitating (feat. DaBaby)           Dua Lipa
# 5              Peaches (feat. Daniel Caesar & Giveon)      Justin Bieber
# 6                            Kiss Me More (feat. SZA)           Doja Cat
# 7                                     Blinding Lights         The Weeknd
# 8                                          Heat Waves      Glass Animals
# 9                                             Beggin'           Måneskin
# 10                             Astronaut In The Ocean        Masked Wolf
# 11                                             DÁKITI          Bad Bunny
# ...

# %%
tracks_df_21.to_csv("2020_2022_outputs/2021_output.csv")
